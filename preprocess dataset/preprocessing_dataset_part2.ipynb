# %% [markdown]
# <div align="center" style="direction:rtl; line-height:300%;">
#     <font face="B Nazanin" size="12"><b>به نام خدا<b></font>
#     <br>
#     <img src="logo.png" alt="لوگو" style="width:250px; height:auto;">
#     <br>
#     <font face="B Nazanin" size="5"><b>دانشگاه صنعتی شریف</b></font>
#     <br><br>
#     <font face="B Nazanin" size="5"><b>بازشناسی گفتار<b></font>
#     <br><br>
#     <font face="B Nazanin" size="5"><b>استاد: جناب آقای دکتر صامتی</b></font>
#     <br><br>
#     <font face="B Nazanin" size="5">دانشجویان: محمد شیرخانی، علی بابابیگ</font>
#     <br><br>
#     <font face="B Nazanin" size="5">زمستان 1403</font>
#     <br><br>
#     <hr>
#     <font face="B Nazanin" size="5">پروژه پایانی</font>
# </div>

# %% [markdown]
# <div style="direction:rtl; line-height:200%; font-family: 'B Nazanin', serif; font-size: 18px; text-align: justify;">
#     <h3>
#         1- نصب کتابخانه‌ها و وارد کردن ماژول‌ها
#     </h3>
#     <p>
#     <div dir="rtl" style="text-align: justify;">
#         در این سلول، ابتدا کتابخانه های مورد نیاز مانند hazm، torchaudio، datasets و noisereduce با استفاده از دستور pip install نصب شده‌اند. سپس، کتابخانه‌ها و ماژول‌های مورد استفاده برای پردازش متن و صدا وارد برنامه شده‌اند.
#     </div>
#     </p>
# </div>

# %%
# !pip install hazm
# !pip install torchaudio
# !pip install datasets
# !pip install noisereduce  # for spectral gating noise reduction

import re
import string
import torch
import torchaudio
import numpy as np
import IPython

from hazm import Normalizer
from datasets import load_dataset, Audio

import noisereduce as nr
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 892.6/892.6 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 9.4 MB/s eta 0:00:00
# ...
#   Created wheel for flashtext: filename=flashtext-2.7-py2.py3-none-any.whl size=9298 sha256=8dc73de07521e23a8d87b6c9aa8a260f6ec0c70b49859d1028d2b6ef30a8da90
#   Stored in directory: /root/.cache/pip/wheels/49/20/47/f03dfa8a7239c54cbc44ff7389eefbf888d2c1873edaaec888
# Successfully built flashtext
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ...

# %% [markdown]
# <div style="direction:rtl; line-height:200%; font-family: 'B Nazanin', serif; font-size: 18px; text-align: justify;">
#     <h3>
#         2- پیش‌پردازش و نرمال‌سازی متن فارسی
#     </h3>
#     <p>
#     <div dir="rtl" style="text-align: justify;">
#         در این سلول ابتدا یک نرمالایزر از کتابخانه Hazm تعریف می‌شود. سپس لیستی از کاراکترهای نامطلوب و نگاشت‌هایی برای تبدیل کاراکترهای فارسی به شکل یکپارچه مشخص می‌شود. در ادامه توابعی برای جایگزینی کاراکترها (multiple_replace) و حذف کاراکترهای اضافی (remove_chars_to_ignore) نوشته شده و نهایتاً تابع normalize_persian_text، متن ورودی را با استفاده از این توابع نرمالسازی می‌کند.
#     </div>
#     </p>
# </div>

# %%
# Hazm normalizer
_normalizer = Normalizer()

# Characters to remove or ignore:
chars_to_ignore = [
    ",", "?", ".", "!", "-", ";", ":", "\"", "“", "%", "‘", "”", "�", "–", "…", "_", "”", "“", "„",
    "#", "!", "؟", "(", ")", "؛", "«", "»", "٬", "ٔ", "َ", "ْ", "ٌ", "ٍ",
    # English letters/digits:
    *list(string.ascii_lowercase + string.digits)
]

# Map some Persian variants to unified forms:
chars_to_mapping = {
    'ك': 'ک', 'دِ': 'د', 'بِ': 'ب', 'زِ': 'ز', 'ذِ': 'ذ', 'شِ': 'ش', 'سِ': 'س',
    'ى': 'ی', 'ي': 'ی', 'أ': 'ا', 'ؤ': 'و', 'ۀ': 'ه', 'ة': 'ه', 'ـ': '',
    "ﯾ": "ی", 'ﯿ': "ی", 'ﺑ': "ب", 'ﺪ': "د", 'ﺮ': "ر", 'ﺴ': "س",
    'ﺷ': "ش", 'ﺸ': "ش", 'ﻫ': "ه", 'ﻭ': "و", "ﮔ": "گ",
    "\u200c": " ", "\u200d": " ", "\u200e": " ", "\u200f": " ", "\ufeff": " ",
}

def multiple_replace(text, mapping):
    """
    Replace all occurrences of the keys in mapping with their values in text.
    """
    pattern = "|".join(map(re.escape, mapping.keys()))
    return re.sub(pattern, lambda m: mapping[m.group()], text)

def remove_chars_to_ignore(text, chars):
    """
    Remove characters defined in chars from text.
    """
    chars_regex = f"[{''.join(chars)}]"
    return re.sub(chars_regex, "", text)

def normalize_persian_text(batch):
    """
    Applies Persian text normalization using Hazm and additional cleaning.
    Expects a batch with the key 'transcription'.
    """
    raw_text = batch["transcription"]
    if not isinstance(raw_text, str):
        # In case of unexpected data format
        raw_text = str(raw_text)

    # Basic cleanup
    text = raw_text.strip().lower()

    # Hazm normalization 
    text = _normalizer.normalize(text)

    # Map Persian variants to unified forms
    text = multiple_replace(text, chars_to_mapping)

    # Remove unwanted characters
    text = remove_chars_to_ignore(text, chars_to_ignore)

    # Replace multiple spaces with single space
    text = re.sub(r"\s+", " ", text).strip()

    # Update the transcription
    batch["transcription"] = text
    return batch

# %% [markdown]
# <div style="direction:rtl; line-height:200%; font-family: 'B Nazanin', serif; font-size: 18px; text-align: justify;">
#     <h3>
#         3- پردازش و نرمال‌سازی اولیه داده‌های صوتی و متنی
#     </h3>
#     <p>
#     <div dir="rtl" style="text-align: justify;">
#         در این بخش، ابتدا دیتاست بارگذاری شده و فرکانس نمونه‌برداری صوت به ۱۶۰۰۰ هرتز تغییر می‌کند. سپس با استفاده از توابع نرمال‌سازی (Hazm به همراه نرمالسازی سفارشی) متن‌های دیتاست پاک‌سازی می‌شوند. در نهایت، نمونه‌ای از متن و صوت قبل و بعد از نرمال‌سازی به نمایش گذاشته می‌شود.
#     </div>
#     </p>
# </div>

# %%
dataset_raw = load_dataset("pourmand1376/asr-farsi-youtube-chunked-10-seconds")

# apply sampling rate conversion for all splits:
dataset_raw = dataset_raw.cast_column("audio", Audio(sampling_rate=16000))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/709 [00:00<?, ?B/s]
# ...
# Resolving data files:   0%|          | 0/32 [00:00<?, ?it/s]
# ...
# train-00000-of-00032.parquet:   0%|          | 0.00/489M [00:00<?, ?B/s]
# train-00001-of-00032.parquet:   0%|          | 0.00/490M [00:00<?, ?B/s]
# train-00002-of-00032.parquet:   0%|          | 0.00/489M [00:00<?, ?B/s]
# train-00003-of-00032.parquet:   0%|          | 0.00/490M [00:00<?, ?B/s]
# ...

# %%
# Apply text normalization functions to all splits:
dataset_pp = dataset_raw.map(
    normalize_persian_text,
    desc="Normalizing text (Hazm + custom cleanup)"
)
# Out:
# ...
# Normalizing text (Hazm + custom cleanup):   0%|          | 0/14151 [00:00<?, ? examples/s]

# %%
print(f"--- Raw Sample 0 ---")
print("Raw Transcription:", dataset_raw['train'][0]["transcription"])
raw_audio_data = dataset_raw['train'][0]["audio"]["array"]
raw_audio_sr = dataset_raw['train'][0]["audio"]["sampling_rate"]
IPython.display.Audio(data=raw_audio_data, rate=raw_audio_sr)
# Out:
# --- Raw Sample 0 ---
# Raw Transcription: بعد از اینکه دیوان عالی ایالات متحده هم سال ۱۹۲۷ این قانون رو تصویب کرد،
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Sample after text normalization:")
print(dataset_pp['train'][0]["transcription"])
# Out:
# Sample after text normalization:
# بعد از اینکه دیوان عالی ایالات متحده هم سال ۱۹۲۷ این قانون رو تصویب کرد،

# %% [markdown]
# <div style="direction:rtl; line-height:200%; font-family: 'B Nazanin', serif; font-size: 18px; text-align: justify;">
#     <h3>
#         4- بارگذاری و استخراج فایل ZIP از Google Drive
#     </h3>
#     <p>
#     <div dir="rtl" style="text-align: justify;">
#         در این بخش، ابتدا Google Drive به محیط Colab متصل می‌شود تا امکان دسترسی به فایل‌های موجود در آن فراهم شود. سپس، فایل ZIP (که شامل صوت‌های پاک‌شده است) از Google Drive به حافظه محلی Colab کپی شده و در یک دایرکتوری مشخص استخراج می‌شود. در پایان، محتویات دایرکتوری استخراج شده لیست شده تا صحت عملیات استخراج تایید گردد.
#     </div>
#     </p>
# </div>

# %%
# Mount Google Drive to access files
from google.colab import drive

# Mount the drive at '/content/drive'
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the path to the zip file in Google Drive
zip_file_path = '/content/drive/MyDrive/ProcessedAudios/denoised_audios_train.zip'

# Define the destination path in Colab's local storage
destination_path = '/content/denoised_audios_train.zip'

# Copy the zip file from Google Drive to Colab's local storage
# !cp "{zip_file_path}" "{destination_path}"

# Verify the file has been copied
import os

if os.path.exists(destination_path):
    print("Zip file has been successfully copied to Colab's local storage.")
else:
    print("Failed to copy the zip file. Please check the file path.")
# Out:
# Zip file has been successfully copied to Colab's local storage.

# %%
# Define the directory where the zip file will be extracted
extract_dir = '/content/denoised_audios_train'

# Create the extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Unzip the file into the specified directory
# !unzip -o "{destination_path}" -d "{extract_dir}"

# Verify the extraction by listing the contents
print(f"Contents of '{extract_dir}':")
print(os.listdir(extract_dir))
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/denoised_audios_train/audio_103311.mp3
#   inflating: /content/denoised_audios_train/audio_60085.mp3
#   inflating: /content/denoised_audios_train/audio_112355.mp3
#   inflating: /content/denoised_audios_train/audio_69758.mp3
#   inflating: /content/denoised_audios_train/audio_52440.mp3
#   inflating: /content/denoised_audios_train/audio_33003.mp3
#   inflating: /content/denoised_audios_train/audio_42836.mp3
#   inflating: /content/denoised_audios_train/audio_64182.mp3
#   inflating: /content/denoised_audios_train/audio_54756.mp3
#   inflating: /content/denoised_audios_train/audio_27028.mp3
#   inflating: /content/denoised_audios_train/audio_6462.mp3
#   inflating: /content/denoised_audios_train/audio_97435.mp3
#   inflating: /content/denoised_audios_train/audio_15994.mp3
#   inflating: /content/denoised_audios_train/audio_68945.mp3
#   inflating: /content/denoised_audios_train/audio_19073.mp3
# ...

# %% [markdown]
# <div style="direction:rtl; line-height:200%; font-family: 'B Nazanin', serif; font-size: 18px; text-align: justify;">
#     <h3>
#         5- ایجاد دیتاست آموزش از صوت‌های دینویز شده
#     </h3>
#     <p>
#     <div dir="rtl" style="text-align: justify;">
#         در این سلول، ابتدا ایندکس‌های فایل‌های صوتی با فرمت audio_<index>.mp3 از پوشه مشخص استخراج می‌شوند. سپس، برای هر ایندکس، متن نرمال‌شده مربوطه از دیتاست پیش‌پردازش‌شده گرفته شده و یک دیکشنری شامل مسیر فایل صوتی و متن مربوط ساخته می‌شود. در پایان، این دیکشنری‌ها به یک دیتاست Hugging Face تبدیل شده و ستون صوت به فرمت Audio cast می‌شود.
#     </div>
#     </p>
# </div>

# %%
import os
import re
import torch
import torchaudio
import numpy as np
import pandas as pd
from tqdm import tqdm
from datasets import Dataset, Audio

# Directory containing denoised (MP3) train audio files
TRAIN_AUDIO_DIR = "denoised_audios_train"

def extract_audio_indices(audio_dir):
    """
    Extracts indices from audio filenames in the given directory.
    Expected filename format: audio_<index>.mp3
    Returns a set of integer indices.
    """
    if not os.path.exists(audio_dir):
        print(f"Audio directory '{audio_dir}' does not exist.")
        return set()

    audio_files = [f for f in os.listdir(audio_dir) if f.endswith(".mp3")]
    indices = set()
    for file in audio_files:
        match = re.match(r"audio_(\d+)\.mp3", file)
        if match:
            indices.add(int(match.group(1)))
    return indices

def create_train_dataset(dataset_pp, audio_dir):
    """
    Creates a Hugging Face Dataset with only two columns: 'audio' and 'transcription'.
    Matches each audio file in 'audio_dir' to the corresponding sample in dataset_pp['train'].
    """
    print(f"Creating train dataset from directory: {audio_dir}")
    available_indices = extract_audio_indices(audio_dir)
    if len(available_indices) == 0:
        print("No audio files found. Returning None.")
        return None

    data_list = []
    for idx in tqdm(sorted(available_indices), desc="Matching audio files with transcriptions"):
        try:
            # Get transcription from the preprocessed dataset
            transcription = dataset_pp["train"][idx]["transcription"]

            # Construct the path to the MP3 file
            audio_file = f"audio_{idx}.mp3"
            audio_path = os.path.join(audio_dir, audio_file)

            if not os.path.exists(audio_path):
                print(f"Audio file '{audio_path}' not found. Skipping index {idx}.")
                continue

            # Append a dictionary with two columns: 'audio' (path) and 'transcription'
            data_list.append({
                "audio": audio_path,
                "transcription": transcription
            })

        except Exception as e:
            print(f"Error at index {idx}: {e}")
            continue

    if not data_list:
        print("No data to create dataset. Returning None.")
        return None

    # Create a Hugging Face Dataset from the list of dictionaries
    dataset = Dataset.from_list(data_list)

    # Convert the 'audio' column to an Audio column 
    dataset = dataset.cast_column("audio", Audio(decode=False))

    print(f"Train dataset created with {len(dataset)} samples.")
    return dataset

# Create the train dataset
train_dataset = create_train_dataset(dataset_pp, TRAIN_AUDIO_DIR)
# Out:
# Creating train dataset from directory: denoised_audios_train
# Matching audio files with transcriptions: 100%|██████████| 113201/113201 [1:09:29<00:00, 27.15it/s]
# Train dataset created with 113201 samples.

# %% [markdown]
# <div style="direction:rtl; line-height:200%; font-family: 'B Nazanin', serif; font-size: 18px; text-align: justify;">
#     <h3>
#         6- ارسال دیتاست train به Hugging Face Hub
#     </h3>
#     <p>
#     <div dir="rtl" style="text-align: justify;">
#         در این سلول، ابتدا یک DatasetDict شامل دیتاست train ساخته می‌شود. سپس با استفاده از توکن و API مربوط به Hugging Face، اعتبارسنجی صورت گرفته و در صورت عدم وجود، ریپازیتوری جدیدی ایجاد می‌شود. در پایان، دیتاست train به ریپازیتوری مشخص شده در Hugging Face Hub ارسال می‌شود.
#     </div>
#     </p>
# </div>

# %%
HF_DATASET_REPO = "asr-farsi-youtube-chunked-10-seconds-train"
HF_TOKEN = "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"

# %%
# Cell: Push train_dataset to Hugging Face Hub

from datasets import DatasetDict
from huggingface_hub import HfApi, HfFolder

# Define your Hugging Face repository and token
HF_DATASET_REPO = "asr-farsi-youtube-chunked-10-seconds"  
HF_TOKEN = "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" 

# Create a DatasetDict containing only the train split
final_dataset = DatasetDict({"train": train_dataset})

# Authenticate with Hugging Face using your token
HfFolder.save_token(HF_TOKEN)
api = HfApi()

# Check if the repository exists; if not, create it
try:
    api.repo_info(repo_id=HF_DATASET_REPO, repo_type="dataset")
    print(f"Repository '{HF_DATASET_REPO}' already exists on Hugging Face Hub.")
except:
    print(f"Repository '{HF_DATASET_REPO}' does not exist. Creating it...")
    api.create_repo(repo_id=HF_DATASET_REPO, repo_type="dataset")
    print(f"Repository '{HF_DATASET_REPO}' created successfully.")

# Push the dataset to the Hugging Face Hub
print(f"\nPushing the train dataset to the Hugging Face Hub repository '{HF_DATASET_REPO}'...")
final_dataset.push_to_hub(HF_DATASET_REPO, token=HF_TOKEN)
print(f"Train dataset successfully pushed to 'hf://{HF_DATASET_REPO}'.")
# Out:
# Repository 'asr-farsi-youtube-chunked-10-seconds' does not exist. Creating it...
# Repository 'asr-farsi-youtube-chunked-10-seconds' created successfully.
#
# Pushing the train dataset to the Hugging Face Hub repository 'asr-farsi-youtube-chunked-10-seconds'...
# ...
# Creating parquet from Arrow format:   0%|          | 0/162 [00:00<?, ?ba/s]
# Train dataset successfully pushed to 'hf://asr-farsi-youtube-chunked-10-seconds'.

# %% [markdown]
# <div style="direction:rtl; line-height:200%; font-family: 'B Nazanin', serif; font-size: 18px; text-align: justify;">
#     <h3>
#         7- پردازش داده‌های مجموعه validation
#     </h3>
#     <p>
#     <div dir="rtl" style="text-align: justify;">
#         در این بخش ابتدا اندازه مجموعه‌های val و test چاپ می‌شود. سپس، مانند بخش train، مجموعه از داده‌های صوتی مجموعه val انتخاب شده و عملیات کاهش نویز، نرمال‌سازی و تبدیل به فرمت MP3 بر روی آن‌ها انجام می‌شود. در پایان، فایل‌های صوتی پردازش شده در پوشه‌ای مشخص ذخیره می‌شوند.
#     </div>
#     </p>
# </div>

# %%
val_size = len(dataset_pp['val'])
test_size = len(dataset_pp['test'])
print(val_size)
print(test_size)
# Out:
# 14151
# 14151

# %%
import os
import torch
import torchaudio
import noisereduce as nr
import numpy as np
from tqdm import tqdm

# Define the range of indices to process
start_idx = 0
end_idx = 14150

# Specify the split to process
split = 'val'

# Access the specific split and create a subset of the main dataset
data_chunk = dataset_pp[split].select(range(start_idx, end_idx + 1))

# Output folder path
output_dir = f"denoised_audios_{split}"
os.makedirs(output_dir, exist_ok=True)  # Ensure the output folder exists

# %%
for i in tqdm(range(len(data_chunk)), desc=f"Processing {split} audios"):
    try:
        # Get audio data
        signal = data_chunk[i]["audio"]["array"]
        sr = data_chunk[i]["audio"]["sampling_rate"]

        # Noise reduction
        denoised_signal = nr.reduce_noise(y=signal, sr=sr)

        # Normalize the signal to prevent clipping
        if np.max(np.abs(denoised_signal)) > 0:
            denoised_signal = denoised_signal / np.max(np.abs(denoised_signal))

        # Convert signal to int16 for saving as MP3 format
        denoised_signal_int16 = np.int16(denoised_signal * 32767)

        # Output file name with index format
        file_idx = start_idx + i
        filename = f"audio_{file_idx}.mp3"
        file_path = os.path.join(output_dir, filename)

        # Convert array to tensor and add channel dimension
        tensor_signal = torch.from_numpy(denoised_signal_int16).unsqueeze(0)

        # Save the MP3 file
        torchaudio.save(file_path, tensor_signal, sr, format="mp3")

    except Exception as e:
        print(f"Error processing file index {start_idx + i}: {e}")
        continue

print(f"All processed audio files have been saved in the folder '{output_dir}' in MP3 format.")
# Out:
# Processing val audios:  29%|██▉       | 4141/14151 [15:27<30:36,  5.45it/s]/usr/local/lib/python3.11/dist-packages/noisereduce/spectralgate/nonstationary.py:70: RuntimeWarning: invalid value encountered in divide
#   sig_mult_above_thresh = (abs_sig_stft - sig_stft_smooth) / sig_stft_smooth
# <ipython-input-25-3d585f93de03>:15: RuntimeWarning: invalid value encountered in cast
#   denoised_signal_int16 = np.int16(denoised_signal * 32767)
# Processing val audios: 100%|██████████| 14151/14151 [53:30<00:00,  4.41it/s]
# All processed audio files have been saved in the folder 'denoised_audios_val' in MP3 format.

# %% [markdown]
# <div style="direction:rtl; line-height:200%; font-family: 'B Nazanin', serif; font-size: 18px; text-align: justify;">
#     <h3>
#         8- فشرده‌سازی و آپلود فایل‌های val به Google Drive
#     </h3>
#     <p>
#     <div dir="rtl" style="text-align: justify;">
#         در این سلول، پوشه‌ی denoised_audios_val که شامل فایل‌های صوتی دینویز مجموعه val است، به صورت یک فایل ZIP فشرده می‌شود. سپس، Google Drive به محیط Colab متصل شده و فایل ZIP به پوشه‌ی مشخصی در درایو کپی می‌شود. در پایان، صحت انتقال با لیست کردن محتویات پوشه بررسی می‌شود.
#     </div>
#     </p>
# </div>

# %%
import os
import shutil
from google.colab import drive
from tqdm import tqdm
import zipfile

# Define the folder to zip and the name of the zip file
folder_to_zip = "denoised_audios_val"
zip_filename = "denoised_audios_val.zip"

# Check if the folder exists
if not os.path.exists(folder_to_zip):
    print(f"The folder '{folder_to_zip}' does not exist. Please check the folder name and try again.")
else:
    # Create a zip archive of the folder
    print(f"Zipping the folder '{folder_to_zip}' into '{zip_filename}'...")

    # Initialize the zip file
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        # Walk through all files and directories in the folder
        for root, dirs, files in tqdm(os.walk(folder_to_zip), desc="Zipping files"):
            for file in files:
                file_path = os.path.join(root, file)
                # Add file to the zip archive with relative path
                zipf.write(file_path, os.path.relpath(file_path, folder_to_zip))

    print(f"Folder '{folder_to_zip}' has been zipped successfully as '{zip_filename}'.")

    # Mount Google Drive
    print("Mounting Google Drive...")
    drive.mount('/content/drive')

    # Define the destination path in Google Drive
    # Example: Save in 'ProcessedAudios' folder inside Drive
    drive_folder = 'ProcessedAudios'
    drive_path = f'/content/drive/MyDrive/{drive_folder}'

    # Create the destination folder in Drive if it doesn't exist
    os.makedirs(drive_path, exist_ok=True)
    drive_destination = os.path.join(drive_path, zip_filename)

    # Verify if the zip file exists before uploading
    if os.path.exists(zip_filename):
        print(f"Uploading '{zip_filename}' to Google Drive at '{drive_destination}'...")
        shutil.copy(zip_filename, drive_destination)
        print(f"'{zip_filename}' has been successfully uploaded to Google Drive in folder '{drive_folder}'.")
    else:
        print(f"Zip file '{zip_filename}' not found. Please ensure the zipping process was successful.")

    # Optional: Verify the upload by listing files in the destination folder
    print("Verifying the uploaded files in Google Drive:")
    uploaded_files = os.listdir(drive_path)
    print(uploaded_files)
# Out:
# Zipping the folder 'denoised_audios_val' into 'denoised_audios_val.zip'...
# Zipping files: 1it [00:32, 32.86s/it]
# Folder 'denoised_audios_val' has been zipped successfully as 'denoised_audios_val.zip'.
# Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Uploading 'denoised_audios_val.zip' to Google Drive at '/content/drive/MyDrive/ProcessedAudios/denoised_audios_val.zip'...
# 'denoised_audios_val.zip' has been successfully uploaded to Google Drive in folder 'ProcessedAudios'.
# Verifying the uploaded files in Google Drive:
# ['denoised_audios_train.zip', 'denoised_audios_val.zip']

# %% [markdown]
# <div style="direction:rtl; line-height:200%; font-family: 'B Nazanin', serif; font-size: 18px; text-align: justify;">
#     <h3>
#         9- ایجاد و ارسال دیتاست val به Hugging Face
#     </h3>
#     <p>
#     <div dir="rtl" style="text-align: justify;">
#         در این بخش، ابتدا ایندکس‌های فایل‌های صوتی موجود در پوشه‌ی denoised_audios_val استخراج می‌شوند. سپس با استفاده از این ایندکس‌ها، برای هر فایل صوتی متن اعتبارسنجی مربوطه از دیتاست پیش‌پردازش‌شده گرفته شده و یک دیتاست Hugging Face با دو ستون audio و transcription ساخته می‌شود. در نهایت، دیتاست به عنوان یک DatasetDict در یک ریپازیتوری مشخص در Hugging Face Hub آپلود می‌شود.
#     </div>
#     </p>
# </div>

# %%
import os
import re
import torch
import torchaudio
import numpy as np
from tqdm import tqdm
from datasets import Dataset, Audio

VAL_AUDIO_DIR = "denoised_audios_val" 

def extract_audio_indices(audio_dir):
    """
    Extracts indices from audio filenames in the given directory.
    Expected filename format: audio_<index>.mp3
    Returns a set of integer indices.
    """
    if not os.path.exists(audio_dir):
        print(f"Audio directory '{audio_dir}' does not exist.")
        return set()

    audio_files = [f for f in os.listdir(audio_dir) if f.endswith(".mp3")]
    indices = set()
    for file in audio_files:
        match = re.match(r"audio_(\d+)\.mp3", file)
        if match:
            indices.add(int(match.group(1)))
    return indices

def create_val_dataset(dataset_pp, audio_dir):
    """
    Creates a Hugging Face Dataset with only two columns: 'audio' and 'transcription'
    for the val split. It matches each audio file in 'audio_dir' to dataset_pp['val'].
    """
    print(f"Creating val dataset from directory: {audio_dir}")
    available_indices = extract_audio_indices(audio_dir)
    if len(available_indices) == 0:
        print("No audio files found. Returning None.")
        return None

    data_list = []
    for idx in tqdm(sorted(available_indices), desc="Matching val audio files with transcriptions"):
        try:
            # Retrieve transcription from the preprocessed val split
            transcription = dataset_pp["val"][idx]["transcription"]

            # Construct the path to the MP3 file
            audio_file = f"audio_{idx}.mp3"
            audio_path = os.path.join(audio_dir, audio_file)

            if not os.path.exists(audio_path):
                print(f"Audio file '{audio_path}' not found. Skipping index {idx}.")
                continue

            data_list.append({
                "audio": audio_path,
                "transcription": transcription
            })

        except Exception as e:
            print(f"Error at index {idx}: {e}")
            continue

    if not data_list:
        print("No data to create dataset. Returning None.")
        return None

    # Create a Hugging Face Dataset from the list of dictionaries
    dataset = Dataset.from_list(data_list)
    # Cast the 'audio' column to an Audio column
    dataset = dataset.cast_column("audio", Audio(decode=False))

    print(f"Val dataset created with {len(dataset)} samples.")
    return dataset

# %%
import os
from datasets import DatasetDict
from huggingface_hub import HfApi, HfFolder

# 1) Create the val dataset
val_dataset = create_val_dataset(dataset_pp, VAL_AUDIO_DIR)

# 2) Put it in a DatasetDict
final_val_dataset = DatasetDict({"val": val_dataset})

# 3) Define the Hugging Face repository and token
HF_DATASET_REPO_VAL = "asr-farsi-youtube-chunked-10-seconds-val"
HF_TOKEN = "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"

# Authenticate with Hugging Face
HfFolder.save_token(HF_TOKEN)
api = HfApi()

# Check if the repository exists; if not, create it
try:
    api.repo_info(repo_id=HF_DATASET_REPO_VAL, repo_type="dataset")
    print(f"Repository '{HF_DATASET_REPO_VAL}' already exists on Hugging Face Hub.")
except Exception:
    print(f"Repository '{HF_DATASET_REPO_VAL}' does not exist. Creating it...")
    api.create_repo(repo_id=HF_DATASET_REPO_VAL, repo_type="dataset")
    print(f"Repository '{HF_DATASET_REPO_VAL}' created successfully.")

# 4) Push the dataset to the Hugging Face Hub
print(f"\nPushing the val dataset to the Hugging Face Hub repository '{HF_DATASET_REPO_VAL}'...")
final_val_dataset.push_to_hub(HF_DATASET_REPO_VAL, token=HF_TOKEN)
print(f"Val dataset successfully pushed to 'hf://{HF_DATASET_REPO_VAL}'.")
# Out:
# Creating val dataset from directory: denoised_audios_val
# Matching val audio files with transcriptions: 100%|██████████| 14151/14151 [08:54<00:00, 26.47it/s]
# Val dataset created with 14151 samples.
# Repository 'asr-farsi-youtube-chunked-10-seconds-val' does not exist. Creating it...
# Repository 'asr-farsi-youtube-chunked-10-seconds-val' created successfully.
#
# Pushing the val dataset to the Hugging Face Hub repository 'asr-farsi-youtube-chunked-10-seconds-val'...
# ...
# Creating parquet from Arrow format:   0%|          | 0/142 [00:00<?, ?ba/s]
# Val dataset successfully pushed to 'hf://asr-farsi-youtube-chunked-10-seconds-val'.

# %% [markdown]
# <div style="direction:rtl; line-height:200%; font-family: 'B Nazanin', serif; font-size: 18px; text-align: justify;">
#     <h3>
#         10- پردازش مجموعه test
#     </h3>
#     <p>
#     <div dir="rtl" style="text-align: justify;">
#         در این قسمت، به‌طور مشابه با مجموعه val، روی داده‌های test عملیات دینویزینگ ، ذخیره‌سازی فایل‌های صوتی و ایجاد دیتاست انجام شده و در نهایت دیتاست ساخته‌شده به Hugging Face Hub ارسال می‌شود
#     </div>
#     </p>
# </div>

# %%
import os
import torch
import torchaudio
import noisereduce as nr
import numpy as np
from tqdm import tqdm

# Define the range of indices to process
start_idx = 0
end_idx = 14150

# Specify the split to process
split = 'test'

# Access the specific split and create a subset of the main dataset
data_chunk = dataset_pp[split].select(range(start_idx, end_idx + 1))

# Output folder path
output_dir = f"denoised_audios_{split}"
os.makedirs(output_dir, exist_ok=True)  # Ensure the output folder exists

# %%
for i in tqdm(range(len(data_chunk)), desc=f"Processing {split} audios"):
    try:
        # Get audio data
        signal = data_chunk[i]["audio"]["array"]
        sr = data_chunk[i]["audio"]["sampling_rate"]

        # Noise reduction
        denoised_signal = nr.reduce_noise(y=signal, sr=sr)

        # Normalize the signal to prevent clipping
        if np.max(np.abs(denoised_signal)) > 0:
            denoised_signal = denoised_signal / np.max(np.abs(denoised_signal))

        # Convert signal to int16 for saving as MP3 format
        denoised_signal_int16 = np.int16(denoised_signal * 32767)

        # Output file name with index format
        file_idx = start_idx + i
        filename = f"audio_{file_idx}.mp3"
        file_path = os.path.join(output_dir, filename)

        # Convert array to tensor and add channel dimension
        tensor_signal = torch.from_numpy(denoised_signal_int16).unsqueeze(0)

        # Save the MP3 file
        torchaudio.save(file_path, tensor_signal, sr, format="mp3")

    except Exception as e:
        print(f"Error processing file index {start_idx + i}: {e}")
        continue

print(f"All processed audio files have been saved in the folder '{output_dir}' in MP3 format.")
# Out:
# Processing test audios: 100%|██████████| 14151/14151 [53:37<00:00,  4.40it/s]
# All processed audio files have been saved in the folder 'denoised_audios_test' in MP3 format.

# %%
import os
import shutil
from google.colab import drive
from tqdm import tqdm
import zipfile

# Define the folder to zip and the name of the zip file
folder_to_zip = "denoised_audios_test"
zip_filename = "denoised_audios_test.zip"

# Check if the folder exists
if not os.path.exists(folder_to_zip):
    print(f"The folder '{folder_to_zip}' does not exist. Please check the folder name and try again.")
else:
    # Create a zip archive of the folder
    print(f"Zipping the folder '{folder_to_zip}' into '{zip_filename}'...")

    # Initialize the zip file
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        # Walk through all files and directories in the folder
        for root, dirs, files in tqdm(os.walk(folder_to_zip), desc="Zipping files"):
            for file in files:
                file_path = os.path.join(root, file)
                # Add file to the zip archive with relative path
                zipf.write(file_path, os.path.relpath(file_path, folder_to_zip))

    print(f"Folder '{folder_to_zip}' has been zipped successfully as '{zip_filename}'.")

    # Mount Google Drive
    print("Mounting Google Drive...")
    drive.mount('/content/drive')

    # Define the destination path in Google Drive
    # Example: Save in 'ProcessedAudios' folder inside Drive
    drive_folder = 'ProcessedAudios'
    drive_path = f'/content/drive/MyDrive/{drive_folder}'

    # Create the destination folder in Drive if it doesn't exist
    os.makedirs(drive_path, exist_ok=True)
    drive_destination = os.path.join(drive_path, zip_filename)

    # Verify if the zip file exists before uploading
    if os.path.exists(zip_filename):
        print(f"Uploading '{zip_filename}' to Google Drive at '{drive_destination}'...")
        shutil.copy(zip_filename, drive_destination)
        print(f"'{zip_filename}' has been successfully uploaded to Google Drive in folder '{drive_folder}'.")
    else:
        print(f"Zip file '{zip_filename}' not found. Please ensure the zipping process was successful.")

    # Verify the upload by listing files in the destination folder
    print("Verifying the uploaded files in Google Drive:")
    uploaded_files = os.listdir(drive_path)
    print(uploaded_files)
# Out:
# Zipping the folder 'denoised_audios_test' into 'denoised_audios_test.zip'...
# Zipping files: 1it [00:35, 35.07s/it]
# Folder 'denoised_audios_test' has been zipped successfully as 'denoised_audios_test.zip'.
# Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Uploading 'denoised_audios_test.zip' to Google Drive at '/content/drive/MyDrive/ProcessedAudios/denoised_audios_test.zip'...
# 'denoised_audios_test.zip' has been successfully uploaded to Google Drive in folder 'ProcessedAudios'.
# Verifying the uploaded files in Google Drive:
# ['denoised_audios_train.zip', 'denoised_audios_val.zip', 'denoised_audios_test.zip']

# %%
import os
import re
import torch
import torchaudio
import numpy as np
from tqdm import tqdm
from datasets import Dataset, Audio

test_AUDIO_DIR = "denoised_audios_test" 

def extract_audio_indices(audio_dir):
    """
    Extracts indices from audio filenames in the given directory.
    Expected filename format: audio_<index>.mp3
    Returns a set of integer indices.
    """
    if not os.path.exists(audio_dir):
        print(f"Audio directory '{audio_dir}' does not exist.")
        return set()

    audio_files = [f for f in os.listdir(audio_dir) if f.endswith(".mp3")]
    indices = set()
    for file in audio_files:
        match = re.match(r"audio_(\d+)\.mp3", file)
        if match:
            indices.add(int(match.group(1)))
    return indices

def create_val_dataset(dataset_pp, audio_dir):
    """
    Creates a Hugging Face Dataset with only two columns: 'audio' and 'transcription'
    for the val split. It matches each audio file in 'audio_dir' to dataset_pp['val'].
    """
    print(f"Creating val dataset from directory: {audio_dir}")
    available_indices = extract_audio_indices(audio_dir)
    if len(available_indices) == 0:
        print("No audio files found. Returning None.")
        return None

    data_list = []
    for idx in tqdm(sorted(available_indices), desc="Matching val audio files with transcriptions"):
        try:
            # Retrieve transcription from the preprocessed val split
            transcription = dataset_pp["test"][idx]["transcription"]

            # Construct the path to the MP3 file
            audio_file = f"audio_{idx}.mp3"
            audio_path = os.path.join(audio_dir, audio_file)

            if not os.path.exists(audio_path):
                print(f"Audio file '{audio_path}' not found. Skipping index {idx}.")
                continue

            data_list.append({
                "audio": audio_path,
                "transcription": transcription
            })

        except Exception as e:
            print(f"Error at index {idx}: {e}")
            continue

    if not data_list:
        print("No data to create dataset. Returning None.")
        return None

    # Create a Hugging Face Dataset from the list of dictionaries
    dataset = Dataset.from_list(data_list)
    # Cast the 'audio' column to an Audio column
    dataset = dataset.cast_column("audio", Audio(decode=False))

    print(f"test dataset created with {len(dataset)} samples.")
    return dataset

# %%
import os
from datasets import DatasetDict
from huggingface_hub import HfApi, HfFolder

# 1) Create the val dataset
test_dataset = create_val_dataset(dataset_pp, test_AUDIO_DIR)

# 2) Put it in a DatasetDict 
final_val_dataset = DatasetDict({"test": test_dataset})

# 3) Define the Hugging Face repository and token
HF_DATASET_REPO_VAL = "asr-farsi-youtube-chunked-10-seconds-test"
HF_TOKEN = "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"

# Authenticate with Hugging Face
HfFolder.save_token(HF_TOKEN)
api = HfApi()

# Check if the repository exists; if not, create it
try:
    api.repo_info(repo_id=HF_DATASET_REPO_VAL, repo_type="dataset")
    print(f"Repository '{HF_DATASET_REPO_VAL}' already exists on Hugging Face Hub.")
except Exception:
    print(f"Repository '{HF_DATASET_REPO_VAL}' does not exist. Creating it...")
    api.create_repo(repo_id=HF_DATASET_REPO_VAL, repo_type="dataset")
    print(f"Repository '{HF_DATASET_REPO_VAL}' created successfully.")

# 4) Push the dataset to the Hugging Face Hub
print(f"\nPushing the val dataset to the Hugging Face Hub repository '{HF_DATASET_REPO_VAL}'...")
final_val_dataset.push_to_hub(HF_DATASET_REPO_VAL, token=HF_TOKEN)
print(f"Val dataset successfully pushed to 'hf://{HF_DATASET_REPO_VAL}'.")
# Out:
# Creating val dataset from directory: denoised_audios_test
# Matching val audio files with transcriptions: 100%|██████████| 14151/14151 [09:03<00:00, 26.05it/s]
# test dataset created with 14151 samples.
# Repository 'asr-farsi-youtube-chunked-10-seconds-test' does not exist. Creating it...
# Repository 'asr-farsi-youtube-chunked-10-seconds-test' created successfully.
#
# Pushing the val dataset to the Hugging Face Hub repository 'asr-farsi-youtube-chunked-10-seconds-test'...
# ...
# Creating parquet from Arrow format:   0%|          | 0/142 [00:00<?, ?ba/s]
# Val dataset successfully pushed to 'hf://asr-farsi-youtube-chunked-10-seconds-test'.
